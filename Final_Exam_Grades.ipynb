# %%
import numpy as np 
import pandas as pd 
import numpy as np
import seaborn as sns

a = np.random.normal(60, 10, 1000)

# %%
sns.distplot(a, hist=True, kde=True, bins=20)

# %%
len(a)
# Out:
# 1000

# %%
np.mean(a)
# Out:
# 59.9233050798154

# %%
np.std(a, ddof=1)
# Out:
# 10.333686937450137

# %%
from scipy.stats import norm

print(norm.sf(70, loc=60, scale=10))

# or

1 - norm.cdf(70, loc=60, scale=10)  #sf is survival factor
# Out:
# 0.15865525393145707
# 0.15865525393145707

# %% [markdown]
# > Instructor is saying take the length of "a" ... wtf that is supposed to have come from idk... then divide it by ... ?something?<br>
# > Info being covered is NOT documented in slides .. only locally on instructors machine, which is being scrolled past too quickly

# %%
norm.cdf(70, loc=60, scale=10) - norm.cdf(50, loc=60, scale=10)
# Out:
# 0.6826894921370859

# %%
b = (a - 60)/10
sns.distplot(b, hist=True, kde=True, bins=20)

# %%
exam_scores = np.random.normal(60, 10, 1000)

normalized_scores = []
for score in exam_scores:
    normal_score = (score-60)/10
    normalized_scores.append(normal_score)
    
sns.distplot(normalized_scores, hist=True, kde=True, bins=20)

np.mean(normalized_scores)
np.std(normalized_scores, ddof=1)
# Out:
# 1.0139124545888223

# %% [markdown]
# ## ZED DISTRIBUTION (std mean 0 deviation 1)

# %%
# other approach

norm.cdf(70, loc=60, scale=10) - norm(cdf(50, loc=60, scale=10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9adbf614a74d> in <module>
#       1 # other approach
#       2
# ----> 3 norm.cdf(70, loc=60, scale=10) - norm(cdf(50, loc=60, scale=10))
#
# NameError: name 'cdf' is not defined

# %% [markdown]
# ### for homwork see sns.displot in Titanic
